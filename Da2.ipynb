# %% [markdown]
# <a href="https://colab.research.google.com/github/dharshila334-byte/Dharshila-/blob/main/Da2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num = int(input("Enter number:"))
  print(num)

except:
  print("Invalid input")
# Out:
# Enter number:22
# 22
