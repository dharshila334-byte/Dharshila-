# %% [markdown]
# <a href="https://colab.research.google.com/github/dharshila334-byte/Dharshila-/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = [1000,2000,3000,4000,6000,8000]

total_sales=sum(sales)
average_sales=total_sales/len(sales)
highest_sales=max(sales)
lowest_sales=min(sales)

print("Monthly sales:",sales)
print("total sales:",total_sales)
print("average sales:",average_sales)
print("highest sales:",highest_sales)
print("lowest sales:",lowest_sales)
# Out:
# Monthly sales: [1000, 2000, 3000, 4000, 6000, 8000]
# total sales: 24000
# average sales: 4000.0
# highest sales: 8000
# lowest sales: 1000

# %% [markdown]
# Day2
